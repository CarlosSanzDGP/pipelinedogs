# %% [markdown]
# # CLEANING

# %%
#Import pandas and numpy for the cleaning process.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('INPUT/NYC_dogs_clean.csv', encoding='latin-1')

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#         Unnamed: 0       X  RowNumber AnimalName AnimalGender  \
# 0                1       1       1753    SHADOW             M
# 1                2       2       2415      ROCCO            M
# 2                3       3       3328      LUIGI            M
# 3                4       4       7537    PETUNIA            F
# 4                5       5       8487      ROMEO            M
# ...            ...     ...        ...        ...          ...
# 121857      121928  121945     122225      ROCKY            M
# 121858      121929  121946     122226      ROXY             F
# 121859      121930  121947     122227  VALENTINA            F
# 121860      121931  121948     122228      VENUS            F
# 121861      121932  121949     122229     WILLOW            F
#
#               AnimalBirthMonth                   BreedName        Borough  \
# 0       01/01/2000 12:00:00 AM                      Beagle       Brooklyn
# ...

# %%
#Drop the columns we do not need
df = df.drop(columns=["Unnamed: 0","LicenseIssuedDate", "X", "RowNumber", "ZipCode", "CommunityDistrict", "CensusTract2010", "NTA", "CityCouncilDistrict", "CongressionalDistrict", "StateSenatorialDistrict", "LicenseExpiredDate"])

# %%
df
# Out:
#        AnimalName AnimalGender        AnimalBirthMonth  \
# 0         SHADOW             M  01/01/2000 12:00:00 AM
# 1           ROCCO            M  10/01/2011 12:00:00 AM
# 2           LUIGI            M  09/01/2005 12:00:00 AM
# 3         PETUNIA            F  08/01/2013 12:00:00 AM
# 4           ROMEO            M  10/01/2008 12:00:00 AM
# ...           ...          ...                     ...
# 121857      ROCKY            M  06/01/2014 12:00:00 AM
# 121858      ROXY             F  10/01/2007 12:00:00 AM
# 121859  VALENTINA            F  05/01/2016 12:00:00 AM
# 121860      VENUS            F  12/01/2010 12:00:00 AM
# 121861     WILLOW            F  03/01/2002 12:00:00 AM
#
#                          BreedName        Borough
# 0                           Beagle       Brooklyn
# 1                            Boxer       Brooklyn
# 2                          Maltese          Bronx
# 3                              Pug       Brooklyn
# ...

# %%
df.isnull().sum().sort_values(ascending=True).head()
#parece que todos los valores estan bien. 
#INTENTAR pasar todos los valores de animalbirthmonth a formato january/2012
# Out:
# AnimalGender          0
# AnimalBirthMonth      0
# BreedName             0
# Borough               0
# AnimalName          235
# dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.Borough.value_counts().sort_index().plot.bar()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.BreedName.value_counts().sort_index().plot.bar()

# %%
#Hay muchisimas mas razas de las que esperaba. Veamos cuantos valores diferentes.
df.BreedName.value_counts().head(20)
# Out:
# Unknown                                 16747
# Yorkshire Terrier                        7768
# Shih Tzu                                 7137
# Chihuahua                                5766
# Maltese                                  4286
# Labrador Retriever                       4195
# American Pit Bull Mix / Pit Bull Mix     3400
# American Pit Bull Terrier/Pit Bull       3339
# Labrador Retriever Crossbreed            2773
# Pomeranian                               2194
# Beagle                                   2105
# Jack Russell Terrier                     2034
# Havanese                                 2027
# Golden Retriever                         1940
# German Shepherd Dog                      1886
# Cocker Spaniel                           1827
# Pug                                      1558
# German Shepherd Crossbreed               1500
# Cavalier King Charles Spaniel            1444
# Shiba Inu                                1410
# Name: BreedName, dtype: int64

# %%
#pues no, esa funcion cuenta el numero de casos de cada raza, yo quiero el numero de valores que tiene la columna
df.BreedName.value_counts()

#maaaadre de dios. 299 razas distintas. Esto puede traer problemas.
# Out:
# Unknown                 16747
# Yorkshire Terrier        7768
# Shih Tzu                 7137
# Chihuahua                5766
# Maltese                  4286
#                         ...
# Portuguese Sheepdog         1
# Bracco Italiano             1
# Peruvian Inca Orchid        1
# Swedish Vallhund            1
# Finnish Lapphund            1
# Name: BreedName, Length: 299, dtype: int64

# %%
df.Borough.value_counts()
# Out:
# Manhattan        42607
# Brooklyn         30351
# Queens           25138
# Bronx            12611
# Staten Island    11155
# Name: Borough, dtype: int64

# %%
#todas las columnas pueden ser 'utiles', no son muchas, las raza mayoritaria es Unknown pero no es mas de un 12-15% 
#299 razas 
df
# Out:
#        AnimalName AnimalGender        AnimalBirthMonth  \
# 0         SHADOW             M  01/01/2000 12:00:00 AM
# 1           ROCCO            M  10/01/2011 12:00:00 AM
# 2           LUIGI            M  09/01/2005 12:00:00 AM
# 3         PETUNIA            F  08/01/2013 12:00:00 AM
# 4           ROMEO            M  10/01/2008 12:00:00 AM
# ...           ...          ...                     ...
# 121857      ROCKY            M  06/01/2014 12:00:00 AM
# 121858      ROXY             F  10/01/2007 12:00:00 AM
# 121859  VALENTINA            F  05/01/2016 12:00:00 AM
# 121860      VENUS            F  12/01/2010 12:00:00 AM
# 121861     WILLOW            F  03/01/2002 12:00:00 AM
#
#                          BreedName        Borough
# 0                           Beagle       Brooklyn
# 1                            Boxer       Brooklyn
# 2                          Maltese          Bronx
# 3                              Pug       Brooklyn
# ...
