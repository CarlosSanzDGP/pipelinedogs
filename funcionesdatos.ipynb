# %%
import pandas as pd
import numpy as np
table = pd.read_csv('./OUTPUT/data.csv')

# %%
#crear una tabla donde esten son los perros de un barrio
table2 = table.Borough == 'Bronx'

# %%
table[table2]
# Out:
#         Unnamed: 0         AnimalName AnimalGender        AnimalBirthMonth  \
# 2                2              LUIGI            M  09/01/2005 12:00:00 AM
# 4                4              ROMEO            M  10/01/2008 12:00:00 AM
# 9                9                LEO            M  01/01/2014 12:00:00 AM
# 13              13              CODY             M  12/01/2012 12:00:00 AM
# 16              16              LADY             F  10/01/2004 12:00:00 AM
# ...            ...                ...          ...                     ...
# 121829      121829             AFRICA            F  04/01/2009 12:00:00 AM
# 121834      121834            SUNDAI             F  01/01/2004 12:00:00 AM
# 121843      121843              DELLA            F  12/01/2014 12:00:00 AM
# 121846      121846  NAME NOT PROVIDED            M  10/01/2016 12:00:00 AM
# 121860      121860              VENUS            F  12/01/2010 12:00:00 AM
#
#                  BreedName Borough
# ...

# %%
#te da una grafica de las principales razas del barrio
table[table2].BreedName.value_counts().head(5).plot(kind = 'barh')

# %%
#te da una tabla con todos lo perros de esa raza en ese barrio.
table3 = (table.Borough=='Bronx') & (table.BreedName=='Maltese')
table[table3]
# Out:
#         Unnamed: 0         AnimalName AnimalGender        AnimalBirthMonth  \
# 2                2              LUIGI            M  09/01/2005 12:00:00 AM
# 4                4              ROMEO            M  10/01/2008 12:00:00 AM
# 13              13              CODY             M  12/01/2012 12:00:00 AM
# 18              18              ANGEL            M  11/01/2003 12:00:00 AM
# 99              99              ONYX             M  04/01/2015 12:00:00 AM
# ...            ...                ...          ...                     ...
# 121122      121122               BABY            F  02/01/2008 12:00:00 AM
# 121257      121257            BASTIAN            M  03/01/2014 12:00:00 AM
# 121748      121748             SHAGGY            M  10/01/2007 12:00:00 AM
# 121768      121768               MIA             F  10/01/2013 12:00:00 AM
# 121846      121846  NAME NOT PROVIDED            M  10/01/2016 12:00:00 AM
#
#        BreedName Borough
# 2        Maltese   Bronx
# ...
